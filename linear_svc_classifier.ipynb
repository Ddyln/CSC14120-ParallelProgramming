# %% [markdown]
# # LinearSVC on GPU2 Features
#
# This notebook trains a LinearSVC classifier on GPU2 autoencoder features with normalization and validation-based early stopping heuristics.
#
# Objectives:
# - Load extracted features and labels
# - Normalize with StandardScaler
# - Train LinearSVC with tuned iterations/tolerance
# - Evaluate and visualize performance

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.svm import LinearSVC
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from pathlib import Path
import time
import pickle

sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (12, 8)

# Config
output_folder = Path("./output")  # Adjust as needed
feature_size = 8 * 8 * 128  # 8192 latent features
expected_min, expected_max = 0.55, 0.62  # LinearSVC baseline often lower than RBF

# %% [markdown]
# ## 1. Load Features from Binary Files
#
# Create `FeatureDataLoader` to read train/test features and labels and validate shapes.

# %%
class FeatureDataLoader:
    """
    Loads training and test features/labels from binary files.
    Features are float32 flattened arrays; labels are uint8.
    """
    def __init__(self, folder: Path, feature_size: int = 8192):
        self.folder = Path(folder)
        self.feature_size = feature_size
        self.num_classes = 10
    
    def _load_bin(self, path: Path, dtype):
        if not path.exists():
            raise FileNotFoundError(f"Missing file: {path}")
        return np.fromfile(path, dtype=dtype)
    
    def load_train(self):
        X_path = self.folder / "gpu_train_features.bin"
        y_path = self.folder / "train_labels.bin"
        X = self._load_bin(X_path, np.float32)
        y = self._load_bin(y_path, np.uint8)
        n = X.size // self.feature_size
        X = X.reshape(n, self.feature_size)
        if y.shape[0] != n:
            raise ValueError(f"Label count {y.shape[0]} != feature samples {n}")
        return X, y
    
    def load_test(self):
        X_path = self.folder / "gpu_test_features.bin"
        y_path = self.folder / "test_labels.bin"
        X = self._load_bin(X_path, np.float32)
        y = self._load_bin(y_path, np.uint8)
        n = X.size // self.feature_size
        X = X.reshape(n, self.feature_size)
        if y.shape[0] != n:
            raise ValueError(f"Label count {y.shape[0]} != feature samples {n}")
        return X, y

# Load with timing
print("Loading features and labels ...")
load_start = time.time()
loader = FeatureDataLoader(output_folder, feature_size)
train_features, train_labels = loader.load_train()
test_features, test_labels = loader.load_test()
load_time = time.time() - load_start
print(f"✓ Loaded: train {train_features.shape} | test {test_features.shape}")
print(f"Feature loading time: {load_time:.2f} s")
# Out:
# Loading features and labels ...
# ✓ Loaded: train (50000, 8192) | test (10000, 8192)
# Feature loading time: 1.09 s
# ✓ Loaded: train (50000, 8192) | test (10000, 8192)
# Feature loading time: 1.09 s

# %% [markdown]
# ## 2. Data Preprocessing and Normalization
#
# Apply `StandardScaler` (fit on train, transform test). Persist scaler.

# %%
train_features = np.nan_to_num(train_features)
test_features = np.nan_to_num(test_features)

print("Fitting StandardScaler on train features ...")
scaler = StandardScaler(with_mean=True, with_std=True)
scale_start = time.time()
scaler.fit(train_features)
train_features_scaled = scaler.transform(train_features)
test_features_scaled = scaler.transform(test_features)
scale_time = time.time() - scale_start

# scaler_path = output_folder / "scaler_linear.pkl"
# with open(scaler_path, "wb") as f:
#     pickle.dump(scaler, f)
# print(f"✓ Scaler saved: {scaler_path}")

print(f"Scaling time: {scale_time:.2f} s")
# Out:
# Fitting StandardScaler on train features ...
# Scaling time: 6.31 s

# %% [markdown]
# ## 3. Initialize and Train LinearSVC
#
# Use `LinearSVC(dual=False, max_iter=2000, tol=1e-4)`. Employ a simple early-stopping heuristic: train on a train/val split and stop if validation accuracy improves less than a threshold across increments.

# %%
print("\n" + "="*60)
print("LinearSVC Training Phase")
print("="*60)

train_start = time.time()
clf = LinearSVC(dual=False, max_iter=3000, tol=1e-4, verbose=1, random_state=42)
# clf.fit(train_features_scaled, train_labels)
clf.fit(train_features, train_labels)

train_time = time.time() - train_start
print(f"Iter: {clf.n_iter_}")
best_model = clf
model_path = output_folder / "linear_svc_model.pkl"
with open(model_path, "wb") as f:
    pickle.dump(best_model, f)
print(f"✓ Trained model saved: {model_path}")
print(f"LinearSVC training time: {train_time:.2f} s ({train_time/60:.2f} min)")
# Out:
# ============================================================
# LinearSVC Training Phase
# ============================================================
# [LibLinear][LibLinear]iter  1 act 2.975e+04 pre 2.974e+04 delta 8.888e-02 f 5.000e+04 |g| 6.695e+05 CG   1
# iter  1 act 2.975e+04 pre 2.974e+04 delta 8.888e-02 f 5.000e+04 |g| 6.695e+05 CG   1
# cg reaches trust region boundary
# iter  2 act 1.769e+03 pre 1.758e+03 delta 1.632e-01 f 2.025e+04 |g| 2.734e+04 CG   1
# cg reaches trust region boundary
# iter  2 act 1.769e+03 pre 1.758e+03 delta 1.632e-01 f 2.025e+04 |g| 2.734e+04 CG   1
# cg reaches trust region boundary
# iter  3 act 2.221e+03 pre 2.290e+03 delta 2.121e-01 f 1.848e+04 |g| 6.112e+04 CG   2
# cg reaches trust region boundary
# iter  3 act 2.221e+03 pre 2.290e+03 delta 2.121e-01 f 1.848e+04 |g| 6.112e+04 CG   2
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter  4 act 1.063e+03 pre 9.791e+02 delta 2.539e-01 f 1.626e+04 |g| 1.893e+04 CG   2
# iter  4 act 1.063e+03 pre 9.791e+02 delta 2.539e-01 f 1.626e+04 |g| 1.893e+04 CG   2
# cg reaches trust region boundary
# iter  5 act 8.261e+02 pre 8.193e+02 delta 3.542e-01 f 1.520e+04 |g| 1.149e+04 CG   3
# cg reaches trust region boundary
# iter  5 act 8.261e+02 pre 8.193e+02 delta 3.542e-01 f 1.520e+04 |g| 1.149e+04 CG   3
# cg reaches trust region boundary
# iter  6 act 7.938e+02 pre 7.617e+02 delta 4.855e-01 f 1.437e+04 |g| 7.000e+03 CG   3
# cg reaches trust region boundary
# iter  6 act 7.938e+02 pre 7.617e+02 delta 4.855e-01 f 1.437e+04 |g| 7.000e+03 CG   3
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter  7 act 6.819e+02 pre 7.026e+02 delta 6.391e-01 f 1.358e+04 |g| 7.019e+03 CG   3
# iter  7 act 6.819e+02 pre 7.026e+02 delta 6.391e-01 f 1.358e+04 |g| 7.019e+03 CG   3
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter  8 act 5.534e+02 pre 5.241e+02 delta 8.839e-01 f 1.289e+04 |g| 8.070e+03 CG   4
# iter  8 act 5.534e+02 pre 5.241e+02 delta 8.839e-01 f 1.289e+04 |g| 8.070e+03 CG   4
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter  9 act 5.949e+02 pre 5.608e+02 delta 1.225e+00 f 1.234e+04 |g| 6.088e+03 CG   6
# iter  9 act 5.949e+02 pre 5.608e+02 delta 1.225e+00 f 1.234e+04 |g| 6.088e+03 CG   6
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 10 act 5.189e+02 pre 5.024e+02 delta 1.341e+00 f 1.174e+04 |g| 5.785e+03 CG   7
# iter 10 act 5.189e+02 pre 5.024e+02 delta 1.341e+00 f 1.174e+04 |g| 5.785e+03 CG   7
# cg reaches trust region boundary
# iter 11 act 5.085e+02 pre 5.060e+02 delta 1.498e+00 f 1.123e+04 |g| 6.610e+03 CG   9
# cg reaches trust region boundary
# iter 11 act 5.085e+02 pre 5.060e+02 delta 1.498e+00 f 1.123e+04 |g| 6.610e+03 CG   9
# iter 12 act 2.039e+01 pre 2.010e+01 delta 1.498e+00 f 1.072e+04 |g| 1.257e+04 CG   1
# iter 12 act 2.039e+01 pre 2.010e+01 delta 1.498e+00 f 1.072e+04 |g| 1.257e+04 CG   1
# cg reaches trust region boundary
# iter 13 act 3.590e+02 pre 3.588e+02 delta 1.512e+00 f 1.070e+04 |g| 1.206e+03 CG  10
# cg reaches trust region boundary
# iter 13 act 3.590e+02 pre 3.588e+02 delta 1.512e+00 f 1.070e+04 |g| 1.206e+03 CG  10
# iter 14 act 1.497e+02 pre 1.448e+02 delta 1.512e+00 f 1.034e+04 |g| 5.273e+03 CG   5
# iter 14 act 1.497e+02 pre 1.448e+02 delta 1.512e+00 f 1.034e+04 |g| 5.273e+03 CG   5
# cg reaches trust region boundary
# iter 15 act 2.332e+02 pre 2.192e+02 delta 1.763e+00 f 1.019e+04 |g| 2.045e+03 CG   9
# cg reaches trust region boundary
# iter 15 act 2.332e+02 pre 2.192e+02 delta 1.763e+00 f 1.019e+04 |g| 2.045e+03 CG   9
# cg reaches trust region boundary
# iter 16 act 2.832e+02 pre 2.982e+02 delta 1.887e+00 f 9.955e+03 |g| 1.274e+03 CG  11
# cg reaches trust region boundary
# iter 16 act 2.832e+02 pre 2.982e+02 delta 1.887e+00 f 9.955e+03 |g| 1.274e+03 CG  11
# cg reaches trust region boundary
# iter 17 act 2.560e+02 pre 2.470e+02 delta 2.128e+00 f 9.672e+03 |g| 3.237e+03 CG  12
# cg reaches trust region boundary
# iter 17 act 2.560e+02 pre 2.470e+02 delta 2.128e+00 f 9.672e+03 |g| 3.237e+03 CG  12
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 18 act 2.228e+02 pre 2.160e+02 delta 2.378e+00 f 9.416e+03 |g| 2.427e+03 CG  13
# iter 18 act 2.228e+02 pre 2.160e+02 delta 2.378e+00 f 9.416e+03 |g| 2.427e+03 CG  13
# iter 19 act 7.616e+01 pre 7.571e+01 delta 2.378e+00 f 9.193e+03 |g| 2.415e+03 CG   9
# iter 19 act 7.616e+01 pre 7.571e+01 delta 2.378e+00 f 9.193e+03 |g| 2.415e+03 CG   9
# cg reaches trust region boundary
# iter 20 act 1.462e+02 pre 1.434e+02 delta 2.785e+00 f 9.117e+03 |g| 9.403e+02 CG  11
# cg reaches trust region boundary
# iter 20 act 1.462e+02 pre 1.434e+02 delta 2.785e+00 f 9.117e+03 |g| 9.403e+02 CG  11
# cg reaches trust region boundary
# iter 21 act 1.860e+02 pre 1.861e+02 delta 2.905e+00 f 8.971e+03 |g| 1.397e+03 CG  17
# cg reaches trust region boundary
# iter 21 act 1.860e+02 pre 1.861e+02 delta 2.905e+00 f 8.971e+03 |g| 1.397e+03 CG  17
# iter 22 act 7.480e+01 pre 7.367e+01 delta 2.905e+00 f 8.785e+03 |g| 1.948e+03 CG  11
# iter 22 act 7.480e+01 pre 7.367e+01 delta 2.905e+00 f 8.785e+03 |g| 1.948e+03 CG  11
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 23 act 1.021e+02 pre 9.874e+01 delta 3.031e+00 f 8.710e+03 |g| 8.082e+02 CG  13
# iter 23 act 1.021e+02 pre 9.874e+01 delta 3.031e+00 f 8.710e+03 |g| 8.082e+02 CG  13
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 24 act 1.339e+02 pre 1.405e+02 delta 3.031e+00 f 8.608e+03 |g| 1.004e+03 CG  19
# iter 24 act 1.339e+02 pre 1.405e+02 delta 3.031e+00 f 8.608e+03 |g| 1.004e+03 CG  19
# iter 25 act 4.453e+01 pre 4.324e+01 delta 3.031e+00 f 8.474e+03 |g| 1.736e+03 CG  10
# iter 25 act 4.453e+01 pre 4.324e+01 delta 3.031e+00 f 8.474e+03 |g| 1.736e+03 CG  10
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 26 act 7.428e+01 pre 7.461e+01 delta 3.169e+00 f 8.430e+03 |g| 4.836e+02 CG  18
# iter 26 act 7.428e+01 pre 7.461e+01 delta 3.169e+00 f 8.430e+03 |g| 4.836e+02 CG  18
# cg reaches trust region boundary
# iter 27 act 7.819e+01 pre 8.647e+01 delta 3.169e+00 f 8.355e+03 |g| 7.587e+02 CG  27
# cg reaches trust region boundary
# iter 27 act 7.819e+01 pre 8.647e+01 delta 3.169e+00 f 8.355e+03 |g| 7.587e+02 CG  27
# iter 28 act 2.076e+01 pre 2.065e+01 delta 3.169e+00 f 8.277e+03 |g| 1.367e+03 CG   9
# iter 28 act 2.076e+01 pre 2.065e+01 delta 3.169e+00 f 8.277e+03 |g| 1.367e+03 CG   9
# cg reaches trust region boundary
# iter 29 act 5.407e+01 pre 5.375e+01 delta 3.222e+00 f 8.256e+03 |g| 2.657e+02 CG  25
# cg reaches trust region boundary
# iter 29 act 5.407e+01 pre 5.375e+01 delta 3.222e+00 f 8.256e+03 |g| 2.657e+02 CG  25
# cg reaches trust region boundary
# iter 30 act 3.906e+01 pre 5.178e+01 delta 3.222e+00 f 8.202e+03 |g| 5.338e+02 CG  33
# cg reaches trust region boundary
# iter 30 act 3.906e+01 pre 5.178e+01 delta 3.222e+00 f 8.202e+03 |g| 5.338e+02 CG  33
# cg reaches trust region boundary
# iter 31 act 4.614e+01 pre 4.715e+01 delta 3.222e+00 f 8.163e+03 |g| 3.587e+02 CG  40
# cg reaches trust region boundary
# iter 31 act 4.614e+01 pre 4.715e+01 delta 3.222e+00 f 8.163e+03 |g| 3.587e+02 CG  40
# iter 32 act 1.074e+01 pre 1.077e+01 delta 3.222e+00 f 8.117e+03 |g| 3.927e+02 CG  23
# iter 32 act 1.074e+01 pre 1.077e+01 delta 3.222e+00 f 8.117e+03 |g| 3.927e+02 CG  23
# cg reaches trust region boundary
# iter 33 act 1.383e+01 pre 1.398e+01 delta 3.222e+00 f 8.106e+03 |g| 9.605e+01 CG  35
# cg reaches trust region boundary
# iter 33 act 1.383e+01 pre 1.398e+01 delta 3.222e+00 f 8.106e+03 |g| 9.605e+01 CG  35
# iter 34 act 7.473e+00 pre 8.211e+00 delta 3.222e+00 f 8.092e+03 |g| 1.128e+02 CG  74
# iter 34 act 7.473e+00 pre 8.211e+00 delta 3.222e+00 f 8.092e+03 |g| 1.128e+02 CG  74
# iter 35 act 6.829e-01 pre 6.823e-01 delta 3.222e+00 f 8.085e+03 |g| 1.136e+02 CG  16
# iter 35 act 6.829e-01 pre 6.823e-01 delta 3.222e+00 f 8.085e+03 |g| 1.136e+02 CG  16
# iter 36 act 5.723e-01 pre 5.750e-01 delta 3.222e+00 f 8.084e+03 |g| 1.172e+01 CG 102
# iter 36 act 5.723e-01 pre 5.750e-01 delta 3.222e+00 f 8.084e+03 |g| 1.172e+01 CG 102
# iter 37 act 1.112e-02 pre 1.113e-02 delta 3.222e+00 f 8.084e+03 |g| 7.301e+00 CG  40
# iter 37 act 1.112e-02 pre 1.113e-02 delta 3.222e+00 f 8.084e+03 |g| 7.301e+00 CG  40
# iter  1 act 3.058e+04 pre 3.055e+04 delta 9.008e-02 f 5.000e+04 |g| 6.790e+05 CG   1
# iter  1 act 3.058e+04 pre 3.055e+04 delta 9.008e-02 f 5.000e+04 |g| 6.790e+05 CG   1
# cg reaches trust region boundary
# iter  2 act 1.173e+03 pre 1.169e+03 delta 1.781e-01 f 1.942e+04 |g| 1.788e+04 CG   2
# cg reaches trust region boundary
# iter  2 act 1.173e+03 pre 1.169e+03 delta 1.781e-01 f 1.942e+04 |g| 1.788e+04 CG   2
# cg reaches trust region boundary
# iter  3 act 1.757e+03 pre 1.779e+03 delta 3.611e-01 f 1.825e+04 |g| 3.652e+04 CG   2
# cg reaches trust region boundary
# iter  3 act 1.757e+03 pre 1.779e+03 delta 3.611e-01 f 1.825e+04 |g| 3.652e+04 CG   2
# cg reaches trust region boundary
# iter  4 act 1.777e+03 pre 1.692e+03 delta 4.123e-01 f 1.649e+04 |g| 1.202e+04 CG   3
# cg reaches trust region boundary
# iter  4 act 1.777e+03 pre 1.692e+03 delta 4.123e-01 f 1.649e+04 |g| 1.202e+04 CG   3
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter  5 act 1.629e+03 pre 1.554e+03 delta 5.899e-01 f 1.471e+04 |g| 1.710e+04 CG   3
# iter  5 act 1.629e+03 pre 1.554e+03 delta 5.899e-01 f 1.471e+04 |g| 1.710e+04 CG   3
# cg reaches trust region boundary
# iter  6 act 1.072e+03 pre 9.667e+02 delta 7.357e-01 f 1.308e+04 |g| 1.195e+04 CG   3
# cg reaches trust region boundary
# iter  6 act 1.072e+03 pre 9.667e+02 delta 7.357e-01 f 1.308e+04 |g| 1.195e+04 CG   3
# cg reaches trust region boundary
# iter  7 act 9.455e+02 pre 8.815e+02 delta 9.272e-01 f 1.201e+04 |g| 1.256e+04 CG   4
# cg reaches trust region boundary
# iter  7 act 9.455e+02 pre 8.815e+02 delta 9.272e-01 f 1.201e+04 |g| 1.256e+04 CG   4
# cg reaches trust region boundary
# iter  8 act 8.872e+02 pre 8.229e+02 delta 1.170e+00 f 1.107e+04 |g| 1.153e+04 CG   6
# cg reaches trust region boundary
# iter  8 act 8.872e+02 pre 8.229e+02 delta 1.170e+00 f 1.107e+04 |g| 1.153e+04 CG   6
# cg reaches trust region boundary
# iter  9 act 7.820e+02 pre 7.392e+02 delta 1.480e+00 f 1.018e+04 |g| 9.161e+03 CG   6
# cg reaches trust region boundary
# iter  9 act 7.820e+02 pre 7.392e+02 delta 1.480e+00 f 1.018e+04 |g| 9.161e+03 CG   6
# cg reaches trust region boundary
# iter 10 act 7.300e+02 pre 6.828e+02 delta 2.020e+00 f 9.398e+03 |g| 7.530e+03 CG   7
# cg reaches trust region boundary
# iter 10 act 7.300e+02 pre 6.828e+02 delta 2.020e+00 f 9.398e+03 |g| 7.530e+03 CG   7
# cg reaches trust region boundary
# iter 11 act 5.882e+02 pre 5.658e+02 delta 2.572e+00 f 8.668e+03 |g| 4.903e+03 CG   9
# cg reaches trust region boundary
# iter 11 act 5.882e+02 pre 5.658e+02 delta 2.572e+00 f 8.668e+03 |g| 4.903e+03 CG   9
# iter 12 act 2.427e+01 pre 2.384e+01 delta 2.572e+00 f 8.079e+03 |g| 1.155e+04 CG   1
# iter 12 act 2.427e+01 pre 2.384e+01 delta 2.572e+00 f 8.079e+03 |g| 1.155e+04 CG   1
# cg reaches trust region boundary
# iter 13 act 4.794e+02 pre 4.539e+02 delta 2.911e+00 f 8.055e+03 |g| 9.143e+02 CG  11
# cg reaches trust region boundary
# iter 13 act 4.794e+02 pre 4.539e+02 delta 2.911e+00 f 8.055e+03 |g| 9.143e+02 CG  11
# iter 14 act 1.242e+02 pre 1.187e+02 delta 2.911e+00 f 7.576e+03 |g| 4.551e+03 CG   4
# iter 14 act 1.242e+02 pre 1.187e+02 delta 2.911e+00 f 7.576e+03 |g| 4.551e+03 CG   4
# cg reaches trust region boundary
# iter 15 act 3.157e+02 pre 3.020e+02 delta 3.399e+00 f 7.451e+03 |g| 1.561e+03 CG  11
# cg reaches trust region boundary
# iter 15 act 3.157e+02 pre 3.020e+02 delta 3.399e+00 f 7.451e+03 |g| 1.561e+03 CG  11
# iter 16 act 1.291e+02 pre 1.273e+02 delta 3.399e+00 f 7.136e+03 |g| 2.500e+03 CG   9
# iter 16 act 1.291e+02 pre 1.273e+02 delta 3.399e+00 f 7.136e+03 |g| 2.500e+03 CG   9
# cg reaches trust region boundary
# iter 17 act 2.485e+02 pre 2.404e+02 delta 4.228e+00 f 7.007e+03 |g| 1.451e+03 CG  11
# cg reaches trust region boundary
# iter 17 act 2.485e+02 pre 2.404e+02 delta 4.228e+00 f 7.007e+03 |g| 1.451e+03 CG  11
# iter 18 act 9.095e+01 pre 9.039e+01 delta 4.228e+00 f 6.758e+03 |g| 1.764e+03 CG   9
# iter 18 act 9.095e+01 pre 9.039e+01 delta 4.228e+00 f 6.758e+03 |g| 1.764e+03 CG   9
# cg reaches trust region boundary
# iter 19 act 1.888e+02 pre 1.804e+02 delta 4.447e+00 f 6.667e+03 |g| 9.480e+02 CG  13
# cg reaches trust region boundary
# iter 19 act 1.888e+02 pre 1.804e+02 delta 4.447e+00 f 6.667e+03 |g| 9.480e+02 CG  13
# iter 20 act 1.279e+02 pre 1.316e+02 delta 4.447e+00 f 6.478e+03 |g| 1.584e+03 CG  16
# iter 20 act 1.279e+02 pre 1.316e+02 delta 4.447e+00 f 6.478e+03 |g| 1.584e+03 CG  16
# cg reaches trust region boundary
# iter 21 act 1.535e+02 pre 1.520e+02 delta 4.952e+00 f 6.351e+03 |g| 1.233e+03 CG  17
# cg reaches trust region boundary
# iter 21 act 1.535e+02 pre 1.520e+02 delta 4.952e+00 f 6.351e+03 |g| 1.233e+03 CG  17
# iter 22 act 7.574e+01 pre 7.806e+01 delta 4.952e+00 f 6.197e+03 |g| 1.068e+03 CG  16
# iter 22 act 7.574e+01 pre 7.806e+01 delta 4.952e+00 f 6.197e+03 |g| 1.068e+03 CG  16
# cg reaches trust region boundary
# iter 23 act 1.121e+02 pre 1.156e+02 delta 5.457e+00 f 6.121e+03 |g| 6.088e+02 CG  18
# cg reaches trust region boundary
# iter 23 act 1.121e+02 pre 1.156e+02 delta 5.457e+00 f 6.121e+03 |g| 6.088e+02 CG  18
# cg reaches trust region boundary
# iter 24 act 1.106e+02 pre 1.195e+02 delta 5.457e+00 f 6.009e+03 |g| 6.658e+02 CG  31
# cg reaches trust region boundary
# iter 24 act 1.106e+02 pre 1.195e+02 delta 5.457e+00 f 6.009e+03 |g| 6.658e+02 CG  31
# iter 25 act 3.849e+01 pre 3.833e+01 delta 5.457e+00 f 5.899e+03 |g| 7.296e+02 CG  16
# iter 25 act 3.849e+01 pre 3.833e+01 delta 5.457e+00 f 5.899e+03 |g| 7.296e+02 CG  16
# cg reaches trust region boundary
# iter 26 act 4.448e+01 pre 4.841e+01 delta 5.457e+00 f 5.860e+03 |g| 2.857e+02 CG  36
# cg reaches trust region boundary
# iter 26 act 4.448e+01 pre 4.841e+01 delta 5.457e+00 f 5.860e+03 |g| 2.857e+02 CG  36
# iter 27 act 1.764e+01 pre 1.802e+01 delta 5.457e+00 f 5.816e+03 |g| 3.719e+02 CG  28
# iter 27 act 1.764e+01 pre 1.802e+01 delta 5.457e+00 f 5.816e+03 |g| 3.719e+02 CG  28
# iter 28 act 1.505e+01 pre 1.520e+01 delta 5.457e+00 f 5.798e+03 |g| 1.069e+02 CG  66
# iter 28 act 1.505e+01 pre 1.520e+01 delta 5.457e+00 f 5.798e+03 |g| 1.069e+02 CG  66
# iter 29 act 4.262e-01 pre 4.272e-01 delta 5.457e+00 f 5.783e+03 |g| 6.120e+01 CG  28
# iter 29 act 4.262e-01 pre 4.272e-01 delta 5.457e+00 f 5.783e+03 |g| 6.120e+01 CG  28
# iter 30 act 3.655e-01 pre 3.666e-01 delta 5.457e+00 f 5.782e+03 |g| 6.982e+00 CG 106
# iter 30 act 3.655e-01 pre 3.666e-01 delta 5.457e+00 f 5.782e+03 |g| 6.982e+00 CG 106
# iter  1 act 3.150e+04 pre 3.146e+04 delta 9.142e-02 f 5.000e+04 |g| 6.891e+05 CG   1
# iter  1 act 3.150e+04 pre 3.146e+04 delta 9.142e-02 f 5.000e+04 |g| 6.891e+05 CG   1
# cg reaches trust region boundary
# iter  2 act 8.472e+02 pre 8.523e+02 delta 1.824e-01 f 1.850e+04 |g| 1.402e+04 CG   2
# cg reaches trust region boundary
# iter  2 act 8.472e+02 pre 8.523e+02 delta 1.824e-01 f 1.850e+04 |g| 1.402e+04 CG   2
# cg reaches trust region boundary
# iter  3 act 7.765e+02 pre 7.659e+02 delta 2.232e-01 f 1.766e+04 |g| 1.156e+04 CG   2
# cg reaches trust region boundary
# iter  3 act 7.765e+02 pre 7.659e+02 delta 2.232e-01 f 1.766e+04 |g| 1.156e+04 CG   2
# cg reaches trust region boundary
# iter  4 act 6.262e+02 pre 6.051e+02 delta 3.018e-01 f 1.688e+04 |g| 1.018e+04 CG   3
# cg reaches trust region boundary
# iter  4 act 6.262e+02 pre 6.051e+02 delta 3.018e-01 f 1.688e+04 |g| 1.018e+04 CG   3
# cg reaches trust region boundary
# iter  5 act 4.368e+02 pre 4.153e+02 delta 4.088e-01 f 1.625e+04 |g| 6.123e+03 CG   3
# cg reaches trust region boundary
# iter  5 act 4.368e+02 pre 4.153e+02 delta 4.088e-01 f 1.625e+04 |g| 6.123e+03 CG   3
# cg reaches trust region boundary
# iter  6 act 4.961e+02 pre 4.894e+02 delta 6.226e-01 f 1.582e+04 |g| 5.842e+03 CG   4
# cg reaches trust region boundary
# iter  6 act 4.961e+02 pre 4.894e+02 delta 6.226e-01 f 1.582e+04 |g| 5.842e+03 CG   4
# cg reaches trust region boundary
# iter  7 act 4.362e+02 pre 4.126e+02 delta 9.356e-01 f 1.532e+04 |g| 4.273e+03 CG   5
# cg reaches trust region boundary
# iter  7 act 4.362e+02 pre 4.126e+02 delta 9.356e-01 f 1.532e+04 |g| 4.273e+03 CG   5
# cg reaches trust region boundary
# iter  8 act 3.967e+02 pre 4.179e+02 delta 9.356e-01 f 1.488e+04 |g| 4.812e+03 CG   6
# cg reaches trust region boundary
# iter  8 act 3.967e+02 pre 4.179e+02 delta 9.356e-01 f 1.488e+04 |g| 4.812e+03 CG   6
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter  9 act 5.051e+02 pre 4.750e+02 delta 1.107e+00 f 1.449e+04 |g| 7.766e+03 CG   7
# iter  9 act 5.051e+02 pre 4.750e+02 delta 1.107e+00 f 1.449e+04 |g| 7.766e+03 CG   7
# cg reaches trust region boundary
# iter 10 act 3.770e+02 pre 3.690e+02 delta 1.263e+00 f 1.398e+04 |g| 6.651e+03 CG   9
# cg reaches trust region boundary
# iter 10 act 3.770e+02 pre 3.690e+02 delta 1.263e+00 f 1.398e+04 |g| 6.651e+03 CG   9
# cg reaches trust region boundary
# iter 11 act 3.634e+02 pre 3.435e+02 delta 1.512e+00 f 1.360e+04 |g| 4.868e+03 CG  10
# cg reaches trust region boundary
# iter 11 act 3.634e+02 pre 3.435e+02 delta 1.512e+00 f 1.360e+04 |g| 4.868e+03 CG  10
# cg reaches trust region boundary
# iter 12 act 2.931e+02 pre 2.835e+02 delta 1.591e+00 f 1.324e+04 |g| 4.297e+03 CG  12
# cg reaches trust region boundary
# iter 12 act 2.931e+02 pre 2.835e+02 delta 1.591e+00 f 1.324e+04 |g| 4.297e+03 CG  12
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 13 act 2.752e+02 pre 2.692e+02 delta 1.671e+00 f 1.295e+04 |g| 3.894e+03 CG  12
# iter 13 act 2.752e+02 pre 2.692e+02 delta 1.671e+00 f 1.295e+04 |g| 3.894e+03 CG  12
# iter 14 act 1.439e+02 pre 1.369e+02 delta 1.671e+00 f 1.267e+04 |g| 3.621e+03 CG  11
# iter 14 act 1.439e+02 pre 1.369e+02 delta 1.671e+00 f 1.267e+04 |g| 3.621e+03 CG  11
# cg reaches trust region boundary
# iter 15 act 1.729e+02 pre 1.708e+02 delta 2.009e+00 f 1.253e+04 |g| 1.945e+03 CG  12
# cg reaches trust region boundary
# iter 15 act 1.729e+02 pre 1.708e+02 delta 2.009e+00 f 1.253e+04 |g| 1.945e+03 CG  12
# cg reaches trust region boundary
# iter 16 act 2.059e+02 pre 2.010e+02 delta 2.390e+00 f 1.236e+04 |g| 1.753e+03 CG  13
# cg reaches trust region boundary
# iter 16 act 2.059e+02 pre 2.010e+02 delta 2.390e+00 f 1.236e+04 |g| 1.753e+03 CG  13
# iter 17 act 6.307e+01 pre 6.218e+01 delta 2.390e+00 f 1.215e+04 |g| 2.183e+03 CG   9
# iter 17 act 6.307e+01 pre 6.218e+01 delta 2.390e+00 f 1.215e+04 |g| 2.183e+03 CG   9
# cg reaches trust region boundary
# iter 18 act 1.356e+02 pre 1.322e+02 delta 2.748e+00 f 1.209e+04 |g| 9.041e+02 CG  12
# cg reaches trust region boundary
# iter 18 act 1.356e+02 pre 1.322e+02 delta 2.748e+00 f 1.209e+04 |g| 9.041e+02 CG  12
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 19 act 1.822e+02 pre 1.828e+02 delta 2.909e+00 f 1.195e+04 |g| 1.511e+03 CG  18
# iter 19 act 1.822e+02 pre 1.828e+02 delta 2.909e+00 f 1.195e+04 |g| 1.511e+03 CG  18
# iter 20 act 5.250e+01 pre 5.216e+01 delta 2.909e+00 f 1.177e+04 |g| 2.236e+03 CG   9
# iter 20 act 5.250e+01 pre 5.216e+01 delta 2.909e+00 f 1.177e+04 |g| 2.236e+03 CG   9
# cg reaches trust region boundary
# iter 21 act 1.182e+02 pre 1.137e+02 delta 3.347e+00 f 1.172e+04 |g| 7.674e+02 CG  18
# cg reaches trust region boundary
# iter 21 act 1.182e+02 pre 1.137e+02 delta 3.347e+00 f 1.172e+04 |g| 7.674e+02 CG  18
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 22 act 1.208e+02 pre 1.295e+02 delta 3.347e+00 f 1.160e+04 |g| 1.227e+03 CG  23
# iter 22 act 1.208e+02 pre 1.295e+02 delta 3.347e+00 f 1.160e+04 |g| 1.227e+03 CG  23
# iter 23 act 4.161e+01 pre 4.105e+01 delta 3.347e+00 f 1.148e+04 |g| 1.851e+03 CG   9
# iter 23 act 4.161e+01 pre 4.105e+01 delta 3.347e+00 f 1.148e+04 |g| 1.851e+03 CG   9
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 24 act 9.179e+01 pre 8.979e+01 delta 3.689e+00 f 1.144e+04 |g| 4.960e+02 CG  23
# iter 24 act 9.179e+01 pre 8.979e+01 delta 3.689e+00 f 1.144e+04 |g| 4.960e+02 CG  23
# iter 25 act 4.300e+01 pre 4.440e+01 delta 3.689e+00 f 1.134e+04 |g| 1.073e+03 CG  18
# iter 25 act 4.300e+01 pre 4.440e+01 delta 3.689e+00 f 1.134e+04 |g| 1.073e+03 CG  18
# cg reaches trust region boundary
# iter 26 act 6.170e+01 pre 6.103e+01 delta 3.789e+00 f 1.130e+04 |g| 6.120e+02 CG  25
# cg reaches trust region boundary
# iter 26 act 6.170e+01 pre 6.103e+01 delta 3.789e+00 f 1.130e+04 |g| 6.120e+02 CG  25
# iter 27 act 3.526e+01 pre 3.603e+01 delta 3.789e+00 f 1.124e+04 |g| 6.717e+02 CG  18
# iter 27 act 3.526e+01 pre 3.603e+01 delta 3.789e+00 f 1.124e+04 |g| 6.717e+02 CG  18
# cg reaches trust region boundary
# iter 28 act 4.335e+01 pre 4.270e+01 delta 3.995e+00 f 1.120e+04 |g| 4.559e+02 CG  24
# cg reaches trust region boundary
# iter 28 act 4.335e+01 pre 4.270e+01 delta 3.995e+00 f 1.120e+04 |g| 4.559e+02 CG  24
# iter 29 act 2.248e+01 pre 2.282e+01 delta 3.995e+00 f 1.116e+04 |g| 4.233e+02 CG  19
# iter 29 act 2.248e+01 pre 2.282e+01 delta 3.995e+00 f 1.116e+04 |g| 4.233e+02 CG  19
# cg reaches trust region boundary
# iter 30 act 2.815e+01 pre 2.842e+01 delta 3.995e+00 f 1.114e+04 |g| 3.030e+02 CG  30
# cg reaches trust region boundary
# iter 30 act 2.815e+01 pre 2.842e+01 delta 3.995e+00 f 1.114e+04 |g| 3.030e+02 CG  30
# iter 31 act 1.325e+01 pre 1.345e+01 delta 3.995e+00 f 1.111e+04 |g| 2.766e+02 CG  28
# iter 31 act 1.325e+01 pre 1.345e+01 delta 3.995e+00 f 1.111e+04 |g| 2.766e+02 CG  28
# cg reaches trust region boundary
# iter 32 act 1.433e+01 pre 1.437e+01 delta 4.030e+00 f 1.110e+04 |g| 1.936e+02 CG  47
# cg reaches trust region boundary
# iter 32 act 1.433e+01 pre 1.437e+01 delta 4.030e+00 f 1.110e+04 |g| 1.936e+02 CG  47
# iter 33 act 2.033e+00 pre 2.036e+00 delta 4.030e+00 f 1.108e+04 |g| 8.811e+01 CG  33
# iter 33 act 2.033e+00 pre 2.036e+00 delta 4.030e+00 f 1.108e+04 |g| 8.811e+01 CG  33
# iter 34 act 1.034e+00 pre 1.035e+00 delta 4.030e+00 f 1.108e+04 |g| 3.031e+01 CG  82
# iter 34 act 1.034e+00 pre 1.035e+00 delta 4.030e+00 f 1.108e+04 |g| 3.031e+01 CG  82
# iter  1 act 3.131e+04 pre 3.128e+04 delta 9.115e-02 f 5.000e+04 |g| 6.871e+05 CG   1
# iter  1 act 3.131e+04 pre 3.128e+04 delta 9.115e-02 f 5.000e+04 |g| 6.871e+05 CG   1
# cg reaches trust region boundary
# iter  2 act 8.826e+02 pre 8.847e+02 delta 1.882e-01 f 1.869e+04 |g| 1.423e+04 CG   2
# cg reaches trust region boundary
# iter  2 act 8.826e+02 pre 8.847e+02 delta 1.882e-01 f 1.869e+04 |g| 1.423e+04 CG   2
# cg reaches trust region boundary
# iter  3 act 8.223e+02 pre 8.243e+02 delta 2.195e-01 f 1.780e+04 |g| 1.310e+04 CG   2
# cg reaches trust region boundary
# iter  3 act 8.223e+02 pre 8.243e+02 delta 2.195e-01 f 1.780e+04 |g| 1.310e+04 CG   2
# cg reaches trust region boundary
# iter  4 act 6.159e+02 pre 6.193e+02 delta 2.607e-01 f 1.698e+04 |g| 1.194e+04 CG   3
# cg reaches trust region boundary
# iter  4 act 6.159e+02 pre 6.193e+02 delta 2.607e-01 f 1.698e+04 |g| 1.194e+04 CG   3
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter  5 act 4.125e+02 pre 3.910e+02 delta 3.164e-01 f 1.637e+04 |g| 6.449e+03 CG   4
# iter  5 act 4.125e+02 pre 3.910e+02 delta 3.164e-01 f 1.637e+04 |g| 6.449e+03 CG   4
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter  6 act 3.728e+02 pre 3.685e+02 delta 4.210e-01 f 1.595e+04 |g| 5.992e+03 CG   4
# iter  6 act 3.728e+02 pre 3.685e+02 delta 4.210e-01 f 1.595e+04 |g| 5.992e+03 CG   4
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter  7 act 3.386e+02 pre 3.229e+02 delta 5.927e-01 f 1.558e+04 |g| 4.264e+03 CG   4
# iter  7 act 3.386e+02 pre 3.229e+02 delta 5.927e-01 f 1.558e+04 |g| 4.264e+03 CG   4
# cg reaches trust region boundary
# iter  8 act 3.525e+02 pre 3.375e+02 delta 7.166e-01 f 1.524e+04 |g| 4.654e+03 CG   6
# cg reaches trust region boundary
# iter  8 act 3.525e+02 pre 3.375e+02 delta 7.166e-01 f 1.524e+04 |g| 4.654e+03 CG   6
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter  9 act 3.343e+02 pre 3.251e+02 delta 7.860e-01 f 1.489e+04 |g| 4.719e+03 CG   6
# iter  9 act 3.343e+02 pre 3.251e+02 delta 7.860e-01 f 1.489e+04 |g| 4.719e+03 CG   6
# cg reaches trust region boundary
# iter 10 act 2.925e+02 pre 2.939e+02 delta 7.860e-01 f 1.455e+04 |g| 4.727e+03 CG   8
# cg reaches trust region boundary
# iter 10 act 2.925e+02 pre 2.939e+02 delta 7.860e-01 f 1.455e+04 |g| 4.727e+03 CG   8
# cg reaches trust region boundary
# iter 11 act 2.750e+02 pre 2.729e+02 delta 8.238e-01 f 1.426e+04 |g| 2.097e+03 CG  10
# cg reaches trust region boundary
# iter 11 act 2.750e+02 pre 2.729e+02 delta 8.238e-01 f 1.426e+04 |g| 2.097e+03 CG  10
# cg reaches trust region boundary
# iter 12 act 2.603e+02 pre 2.462e+02 delta 1.066e+00 f 1.399e+04 |g| 4.228e+03 CG  10
# cg reaches trust region boundary
# iter 12 act 2.603e+02 pre 2.462e+02 delta 1.066e+00 f 1.399e+04 |g| 4.228e+03 CG  10
# cg reaches trust region boundary
# iter 13 act 2.221e+02 pre 2.173e+02 delta 1.263e+00 f 1.373e+04 |g| 2.790e+03 CG  10
# cg reaches trust region boundary
# iter 13 act 2.221e+02 pre 2.173e+02 delta 1.263e+00 f 1.373e+04 |g| 2.790e+03 CG  10
# cg reaches trust region boundary
# iter 14 act 2.424e+02 pre 2.393e+02 delta 1.480e+00 f 1.350e+04 |g| 2.597e+03 CG  11
# cg reaches trust region boundary
# iter 14 act 2.424e+02 pre 2.393e+02 delta 1.480e+00 f 1.350e+04 |g| 2.597e+03 CG  11
# cg reaches trust region boundary
# iter 15 act 2.327e+02 pre 2.241e+02 delta 1.752e+00 f 1.326e+04 |g| 2.459e+03 CG  12
# cg reaches trust region boundary
# iter 15 act 2.327e+02 pre 2.241e+02 delta 1.752e+00 f 1.326e+04 |g| 2.459e+03 CG  12
# cg reaches trust region boundary
# iter 16 act 2.063e+02 pre 2.042e+02 delta 1.915e+00 f 1.303e+04 |g| 2.562e+03 CG  13
# cg reaches trust region boundary
# iter 16 act 2.063e+02 pre 2.042e+02 delta 1.915e+00 f 1.303e+04 |g| 2.562e+03 CG  13
# cg reaches trust region boundary
# iter 17 act 2.002e+02 pre 1.925e+02 delta 2.114e+00 f 1.282e+04 |g| 2.248e+03 CG  16
# cg reaches trust region boundary
# iter 17 act 2.002e+02 pre 1.925e+02 delta 2.114e+00 f 1.282e+04 |g| 2.248e+03 CG  16
# cg reaches trust region boundary
# iter 18 act 1.799e+02 pre 1.800e+02 delta 2.322e+00 f 1.262e+04 |g| 2.187e+03 CG  16
# cg reaches trust region boundary
# iter 18 act 1.799e+02 pre 1.800e+02 delta 2.322e+00 f 1.262e+04 |g| 2.187e+03 CG  16
# cg reaches trust region boundary
# iter 19 act 1.625e+02 pre 1.588e+02 delta 2.558e+00 f 1.244e+04 |g| 1.957e+03 CG  18
# cg reaches trust region boundary
# iter 19 act 1.625e+02 pre 1.588e+02 delta 2.558e+00 f 1.244e+04 |g| 1.957e+03 CG  18
# cg reaches trust region boundary
# iter 20 act 1.432e+02 pre 1.442e+02 delta 2.622e+00 f 1.228e+04 |g| 1.764e+03 CG  21
# cg reaches trust region boundary
# iter 20 act 1.432e+02 pre 1.442e+02 delta 2.622e+00 f 1.228e+04 |g| 1.764e+03 CG  21
# cg reaches trust region boundary
# iter 21 act 1.316e+02 pre 1.328e+02 delta 2.707e+00 f 1.214e+04 |g| 1.077e+03 CG  23
# cg reaches trust region boundary
# iter 21 act 1.316e+02 pre 1.328e+02 delta 2.707e+00 f 1.214e+04 |g| 1.077e+03 CG  23
# iter 22 act 5.649e+01 pre 5.650e+01 delta 2.707e+00 f 1.201e+04 |g| 1.539e+03 CG  16
# iter 22 act 5.649e+01 pre 5.650e+01 delta 2.707e+00 f 1.201e+04 |g| 1.539e+03 CG  16
# cg reaches trust region boundary
# iter 23 act 7.349e+01 pre 7.252e+01 delta 2.836e+00 f 1.195e+04 |g| 6.726e+02 CG  18
# cg reaches trust region boundary
# iter 23 act 7.349e+01 pre 7.252e+01 delta 2.836e+00 f 1.195e+04 |g| 6.726e+02 CG  18
# cg reaches trust region boundary
# iter 24 act 9.328e+01 pre 9.635e+01 delta 2.836e+00 f 1.188e+04 |g| 8.249e+02 CG  26
# cg reaches trust region boundary
# iter 24 act 9.328e+01 pre 9.635e+01 delta 2.836e+00 f 1.188e+04 |g| 8.249e+02 CG  26
# iter 25 act 3.601e+01 pre 3.600e+01 delta 2.836e+00 f 1.178e+04 |g| 1.243e+03 CG  13
# iter 25 act 3.601e+01 pre 3.600e+01 delta 2.836e+00 f 1.178e+04 |g| 1.243e+03 CG  13
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 26 act 4.983e+01 pre 4.899e+01 delta 2.907e+00 f 1.175e+04 |g| 4.329e+02 CG  22
# iter 26 act 4.983e+01 pre 4.899e+01 delta 2.907e+00 f 1.175e+04 |g| 4.329e+02 CG  22
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 27 act 5.954e+01 pre 6.392e+01 delta 2.907e+00 f 1.170e+04 |g| 5.700e+02 CG  33
# iter 27 act 5.954e+01 pre 6.392e+01 delta 2.907e+00 f 1.170e+04 |g| 5.700e+02 CG  33
# iter 28 act 2.143e+01 pre 2.126e+01 delta 2.907e+00 f 1.164e+04 |g| 9.204e+02 CG  15
# iter 28 act 2.143e+01 pre 2.126e+01 delta 2.907e+00 f 1.164e+04 |g| 9.204e+02 CG  15
# cg reaches trust region boundary
# iter 29 act 3.318e+01 pre 3.285e+01 delta 2.941e+00 f 1.162e+04 |g| 2.477e+02 CG  31
# cg reaches trust region boundary
# iter 29 act 3.318e+01 pre 3.285e+01 delta 2.941e+00 f 1.162e+04 |g| 2.477e+02 CG  31
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 30 act 3.171e+01 pre 3.713e+01 delta 2.941e+00 f 1.158e+04 |g| 4.095e+02 CG  42
# iter 30 act 3.171e+01 pre 3.713e+01 delta 2.941e+00 f 1.158e+04 |g| 4.095e+02 CG  42
# iter 31 act 1.124e+01 pre 1.115e+01 delta 2.941e+00 f 1.155e+04 |g| 6.255e+02 CG  16
# iter 31 act 1.124e+01 pre 1.115e+01 delta 2.941e+00 f 1.155e+04 |g| 6.255e+02 CG  16
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 32 act 1.746e+01 pre 1.743e+01 delta 3.019e+00 f 1.154e+04 |g| 1.201e+02 CG  43
# iter 32 act 1.746e+01 pre 1.743e+01 delta 3.019e+00 f 1.154e+04 |g| 1.201e+02 CG  43
# iter 33 act 6.326e+00 pre 6.611e+00 delta 3.019e+00 f 1.152e+04 |g| 2.218e+02 CG  35
# iter 33 act 6.326e+00 pre 6.611e+00 delta 3.019e+00 f 1.152e+04 |g| 2.218e+02 CG  35
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 34 act 6.793e+00 pre 7.395e+00 delta 3.019e+00 f 1.152e+04 |g| 1.060e+02 CG  58
# iter 34 act 6.793e+00 pre 7.395e+00 delta 3.019e+00 f 1.152e+04 |g| 1.060e+02 CG  58
# iter 35 act 1.199e+00 pre 1.201e+00 delta 3.019e+00 f 1.151e+04 |g| 4.820e+01 CG  40
# iter 35 act 1.199e+00 pre 1.201e+00 delta 3.019e+00 f 1.151e+04 |g| 4.820e+01 CG  40
# iter 36 act 3.092e-01 pre 3.095e-01 delta 3.019e+00 f 1.151e+04 |g| 1.143e+01 CG 113
# iter 36 act 3.092e-01 pre 3.095e-01 delta 3.019e+00 f 1.151e+04 |g| 1.143e+01 CG 113
# iter  1 act 3.212e+04 pre 3.207e+04 delta 9.233e-02 f 5.000e+04 |g| 6.958e+05 CG   1
# iter  1 act 3.212e+04 pre 3.207e+04 delta 9.233e-02 f 5.000e+04 |g| 6.958e+05 CG   1
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter  2 act 9.209e+02 pre 9.163e+02 delta 1.834e-01 f 1.788e+04 |g| 1.550e+04 CG   2
# iter  2 act 9.209e+02 pre 9.163e+02 delta 1.834e-01 f 1.788e+04 |g| 1.550e+04 CG   2
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter  3 act 7.653e+02 pre 7.345e+02 delta 2.025e-01 f 1.696e+04 |g| 1.083e+04 CG   2
# iter  3 act 7.653e+02 pre 7.345e+02 delta 2.025e-01 f 1.696e+04 |g| 1.083e+04 CG   2
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter  4 act 4.785e+02 pre 4.700e+02 delta 2.283e-01 f 1.619e+04 |g| 1.132e+04 CG   3
# iter  4 act 4.785e+02 pre 4.700e+02 delta 2.283e-01 f 1.619e+04 |g| 1.132e+04 CG   3
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter  5 act 2.987e+02 pre 2.660e+02 delta 2.826e-01 f 1.572e+04 |g| 7.945e+03 CG   4
# iter  5 act 2.987e+02 pre 2.660e+02 delta 2.826e-01 f 1.572e+04 |g| 7.945e+03 CG   4
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter  6 act 3.540e+02 pre 3.601e+02 delta 4.086e-01 f 1.542e+04 |g| 6.274e+03 CG   4
# iter  6 act 3.540e+02 pre 3.601e+02 delta 4.086e-01 f 1.542e+04 |g| 6.274e+03 CG   4
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter  7 act 3.845e+02 pre 3.673e+02 delta 7.798e-01 f 1.506e+04 |g| 4.125e+03 CG   4
# iter  7 act 3.845e+02 pre 3.673e+02 delta 7.798e-01 f 1.506e+04 |g| 4.125e+03 CG   4
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter  8 act 4.374e+02 pre 4.344e+02 delta 9.504e-01 f 1.468e+04 |g| 3.644e+03 CG   5
# iter  8 act 4.374e+02 pre 4.344e+02 delta 9.504e-01 f 1.468e+04 |g| 3.644e+03 CG   5
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter  9 act 5.513e+02 pre 5.289e+02 delta 1.376e+00 f 1.424e+04 |g| 6.399e+03 CG   6
# iter  9 act 5.513e+02 pre 5.289e+02 delta 1.376e+00 f 1.424e+04 |g| 6.399e+03 CG   6
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 10 act 4.932e+02 pre 4.513e+02 delta 1.792e+00 f 1.369e+04 |g| 6.036e+03 CG   7
# iter 10 act 4.932e+02 pre 4.513e+02 delta 1.792e+00 f 1.369e+04 |g| 6.036e+03 CG   7
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 11 act 4.411e+02 pre 4.587e+02 delta 1.894e+00 f 1.320e+04 |g| 5.621e+03 CG  10
# iter 11 act 4.411e+02 pre 4.587e+02 delta 1.894e+00 f 1.320e+04 |g| 5.621e+03 CG  10
# iter 12 act 1.613e+02 pre 1.521e+02 delta 1.894e+00 f 1.276e+04 |g| 6.320e+03 CG   5
# iter 12 act 1.613e+02 pre 1.521e+02 delta 1.894e+00 f 1.276e+04 |g| 6.320e+03 CG   5
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 13 act 2.886e+02 pre 2.765e+02 delta 2.422e+00 f 1.259e+04 |g| 2.299e+03 CG   9
# iter 13 act 2.886e+02 pre 2.765e+02 delta 2.422e+00 f 1.259e+04 |g| 2.299e+03 CG   9
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 14 act 3.282e+02 pre 3.275e+02 delta 2.658e+00 f 1.231e+04 |g| 3.407e+03 CG  13
# iter 14 act 3.282e+02 pre 3.275e+02 delta 2.658e+00 f 1.231e+04 |g| 3.407e+03 CG  13
# iter 15 act 8.590e+01 pre 8.253e+01 delta 2.658e+00 f 1.198e+04 |g| 4.076e+03 CG   5
# iter 15 act 8.590e+01 pre 8.253e+01 delta 2.658e+00 f 1.198e+04 |g| 4.076e+03 CG   5
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 16 act 2.105e+02 pre 1.972e+02 delta 3.024e+00 f 1.189e+04 |g| 1.206e+03 CG  13
# iter 16 act 2.105e+02 pre 1.972e+02 delta 3.024e+00 f 1.189e+04 |g| 1.206e+03 CG  13
# iter 17 act 9.673e+01 pre 1.001e+02 delta 3.024e+00 f 1.168e+04 |g| 2.478e+03 CG  11
# iter 17 act 9.673e+01 pre 1.001e+02 delta 3.024e+00 f 1.168e+04 |g| 2.478e+03 CG  11
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 18 act 1.657e+02 pre 1.583e+02 delta 3.529e+00 f 1.158e+04 |g| 1.432e+03 CG  13
# iter 18 act 1.657e+02 pre 1.583e+02 delta 3.529e+00 f 1.158e+04 |g| 1.432e+03 CG  13
# iter 19 act 7.222e+01 pre 7.291e+01 delta 3.529e+00 f 1.142e+04 |g| 1.731e+03 CG  10
# iter 19 act 7.222e+01 pre 7.291e+01 delta 3.529e+00 f 1.142e+04 |g| 1.731e+03 CG  10
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 20 act 1.338e+02 pre 1.286e+02 delta 4.010e+00 f 1.135e+04 |g| 9.861e+02 CG  13
# iter 20 act 1.338e+02 pre 1.286e+02 delta 4.010e+00 f 1.135e+04 |g| 9.861e+02 CG  13
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 21 act 1.558e+02 pre 1.625e+02 delta 4.010e+00 f 1.121e+04 |g| 1.321e+03 CG  24
# iter 21 act 1.558e+02 pre 1.625e+02 delta 4.010e+00 f 1.121e+04 |g| 1.321e+03 CG  24
# iter 22 act 4.569e+01 pre 4.393e+01 delta 4.010e+00 f 1.106e+04 |g| 2.160e+03 CG   9
# iter 22 act 4.569e+01 pre 4.393e+01 delta 4.010e+00 f 1.106e+04 |g| 2.160e+03 CG   9
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 23 act 9.628e+01 pre 9.465e+01 delta 4.198e+00 f 1.101e+04 |g| 5.595e+02 CG  24
# iter 23 act 9.628e+01 pre 9.465e+01 delta 4.198e+00 f 1.101e+04 |g| 5.595e+02 CG  24
# iter 24 act 3.346e+01 pre 3.325e+01 delta 4.198e+00 f 1.092e+04 |g| 1.133e+03 CG  12
# iter 24 act 3.346e+01 pre 3.325e+01 delta 4.198e+00 f 1.092e+04 |g| 1.133e+03 CG  12
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 25 act 6.373e+01 pre 6.435e+01 delta 4.230e+00 f 1.088e+04 |g| 4.216e+02 CG  28
# iter 25 act 6.373e+01 pre 6.435e+01 delta 4.230e+00 f 1.088e+04 |g| 4.216e+02 CG  28
# iter 26 act 2.855e+01 pre 2.832e+01 delta 4.230e+00 f 1.082e+04 |g| 8.050e+02 CG  17
# iter 26 act 2.855e+01 pre 2.832e+01 delta 4.230e+00 f 1.082e+04 |g| 8.050e+02 CG  17
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 27 act 4.128e+01 pre 4.094e+01 delta 4.345e+00 f 1.079e+04 |g| 3.589e+02 CG  31
# iter 27 act 4.128e+01 pre 4.094e+01 delta 4.345e+00 f 1.079e+04 |g| 3.589e+02 CG  31
# iter 28 act 1.746e+01 pre 1.775e+01 delta 4.345e+00 f 1.075e+04 |g| 4.696e+02 CG  23
# iter 28 act 1.746e+01 pre 1.775e+01 delta 4.345e+00 f 1.075e+04 |g| 4.696e+02 CG  23
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 29 act 2.100e+01 pre 2.121e+01 delta 4.345e+00 f 1.073e+04 |g| 2.549e+02 CG  36
# iter 29 act 2.100e+01 pre 2.121e+01 delta 4.345e+00 f 1.073e+04 |g| 2.549e+02 CG  36
# iter 30 act 5.633e+00 pre 5.671e+00 delta 4.345e+00 f 1.071e+04 |g| 1.744e+02 CG  29
# iter 30 act 5.633e+00 pre 5.671e+00 delta 4.345e+00 f 1.071e+04 |g| 1.744e+02 CG  29
# iter 31 act 3.673e+00 pre 3.691e+00 delta 4.345e+00 f 1.070e+04 |g| 7.894e+01 CG  63
# iter 31 act 3.673e+00 pre 3.691e+00 delta 4.345e+00 f 1.070e+04 |g| 7.894e+01 CG  63
# iter 32 act 2.336e-01 pre 2.431e-01 delta 4.345e+00 f 1.070e+04 |g| 1.993e+01 CG  53
# iter 32 act 2.336e-01 pre 2.431e-01 delta 4.345e+00 f 1.070e+04 |g| 1.993e+01 CG  53
# iter  1 act 3.117e+04 pre 3.113e+04 delta 9.093e-02 f 5.000e+04 |g| 6.855e+05 CG   1
# iter  1 act 3.117e+04 pre 3.113e+04 delta 9.093e-02 f 5.000e+04 |g| 6.855e+05 CG   1
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter  2 act 8.706e+02 pre 8.632e+02 delta 2.019e-01 f 1.883e+04 |g| 1.390e+04 CG   2
# iter  2 act 8.706e+02 pre 8.632e+02 delta 2.019e-01 f 1.883e+04 |g| 1.390e+04 CG   2
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter  3 act 1.281e+03 pre 1.297e+03 delta 3.941e-01 f 1.796e+04 |g| 1.312e+04 CG   2
# iter  3 act 1.281e+03 pre 1.297e+03 delta 3.941e-01 f 1.796e+04 |g| 1.312e+04 CG   2
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter  4 act 1.175e+03 pre 1.094e+03 delta 4.819e-01 f 1.668e+04 |g| 1.208e+04 CG   3
# iter  4 act 1.175e+03 pre 1.094e+03 delta 4.819e-01 f 1.668e+04 |g| 1.208e+04 CG   3
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter  5 act 5.956e+02 pre 6.639e+02 delta 4.819e-01 f 1.551e+04 |g| 1.067e+04 CG   3
# iter  5 act 5.956e+02 pre 6.639e+02 delta 4.819e-01 f 1.551e+04 |g| 1.067e+04 CG   3
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter  6 act 7.360e+02 pre 6.624e+02 delta 6.238e-01 f 1.491e+04 |g| 1.413e+04 CG   5
# iter  6 act 7.360e+02 pre 6.624e+02 delta 6.238e-01 f 1.491e+04 |g| 1.413e+04 CG   5
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter  7 act 4.314e+02 pre 4.344e+02 delta 6.597e-01 f 1.418e+04 |g| 8.982e+03 CG   5
# iter  7 act 4.314e+02 pre 4.344e+02 delta 6.597e-01 f 1.418e+04 |g| 8.982e+03 CG   5
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter  8 act 5.392e+02 pre 5.129e+02 delta 9.130e-01 f 1.374e+04 |g| 6.354e+03 CG   6
# iter  8 act 5.392e+02 pre 5.129e+02 delta 9.130e-01 f 1.374e+04 |g| 6.354e+03 CG   6
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter  9 act 3.890e+02 pre 3.600e+02 delta 1.039e+00 f 1.321e+04 |g| 4.980e+03 CG   7
# iter  9 act 3.890e+02 pre 3.600e+02 delta 1.039e+00 f 1.321e+04 |g| 4.980e+03 CG   7
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 10 act 4.187e+02 pre 4.173e+02 delta 1.168e+00 f 1.282e+04 |g| 5.241e+03 CG   7
# iter 10 act 4.187e+02 pre 4.173e+02 delta 1.168e+00 f 1.282e+04 |g| 5.241e+03 CG   7
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 11 act 3.701e+02 pre 3.205e+02 delta 1.324e+00 f 1.240e+04 |g| 5.908e+03 CG   8
# iter 11 act 3.701e+02 pre 3.205e+02 delta 1.324e+00 f 1.240e+04 |g| 5.908e+03 CG   8
# iter 12 act 1.692e+01 pre 1.717e+01 delta 1.324e+00 f 1.203e+04 |g| 1.076e+04 CG   1
# iter 12 act 1.692e+01 pre 1.717e+01 delta 1.324e+00 f 1.203e+04 |g| 1.076e+04 CG   1
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 13 act 2.791e+02 pre 2.938e+02 delta 1.393e+00 f 1.201e+04 |g| 1.101e+03 CG  10
# iter 13 act 2.791e+02 pre 2.938e+02 delta 1.393e+00 f 1.201e+04 |g| 1.101e+03 CG  10
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 14 act 2.934e+02 pre 2.772e+02 delta 1.678e+00 f 1.173e+04 |g| 3.995e+03 CG  11
# iter 14 act 2.934e+02 pre 2.772e+02 delta 1.678e+00 f 1.173e+04 |g| 3.995e+03 CG  11
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 15 act 2.463e+02 pre 2.405e+02 delta 1.955e+00 f 1.144e+04 |g| 3.197e+03 CG  12
# iter 15 act 2.463e+02 pre 2.405e+02 delta 1.955e+00 f 1.144e+04 |g| 3.197e+03 CG  12
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 16 act 2.271e+02 pre 2.279e+02 delta 2.143e+00 f 1.119e+04 |g| 2.302e+03 CG  13
# iter 16 act 2.271e+02 pre 2.279e+02 delta 2.143e+00 f 1.119e+04 |g| 2.302e+03 CG  13
# iter 17 act 9.133e+01 pre 8.757e+01 delta 2.143e+00 f 1.096e+04 |g| 2.823e+03 CG  10
# iter 17 act 9.133e+01 pre 8.757e+01 delta 2.143e+00 f 1.096e+04 |g| 2.823e+03 CG  10
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 18 act 1.458e+02 pre 1.443e+02 delta 2.482e+00 f 1.087e+04 |g| 1.360e+03 CG  12
# iter 18 act 1.458e+02 pre 1.443e+02 delta 2.482e+00 f 1.087e+04 |g| 1.360e+03 CG  12
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 19 act 1.879e+02 pre 1.881e+02 delta 2.618e+00 f 1.073e+04 |g| 1.483e+03 CG  16
# iter 19 act 1.879e+02 pre 1.881e+02 delta 2.618e+00 f 1.073e+04 |g| 1.483e+03 CG  16
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 20 act 1.723e+02 pre 1.670e+02 delta 2.839e+00 f 1.054e+04 |g| 1.562e+03 CG  19
# iter 20 act 1.723e+02 pre 1.670e+02 delta 2.839e+00 f 1.054e+04 |g| 1.562e+03 CG  19
# iter 21 act 6.570e+01 pre 6.664e+01 delta 2.839e+00 f 1.037e+04 |g| 1.827e+03 CG  13
# iter 21 act 6.570e+01 pre 6.664e+01 delta 2.839e+00 f 1.037e+04 |g| 1.827e+03 CG  13
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 22 act 9.467e+01 pre 9.247e+01 delta 2.915e+00 f 1.030e+04 |g| 7.460e+02 CG  17
# iter 22 act 9.467e+01 pre 9.247e+01 delta 2.915e+00 f 1.030e+04 |g| 7.460e+02 CG  17
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 23 act 1.159e+02 pre 1.277e+02 delta 2.915e+00 f 1.021e+04 |g| 1.115e+03 CG  24
# iter 23 act 1.159e+02 pre 1.277e+02 delta 2.915e+00 f 1.021e+04 |g| 1.115e+03 CG  24
# iter 24 act 5.052e+01 pre 5.089e+01 delta 2.915e+00 f 1.009e+04 |g| 1.702e+03 CG  11
# iter 24 act 5.052e+01 pre 5.089e+01 delta 2.915e+00 f 1.009e+04 |g| 1.702e+03 CG  11
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 25 act 6.874e+01 pre 6.602e+01 delta 3.096e+00 f 1.004e+04 |g| 5.934e+02 CG  19
# iter 25 act 6.874e+01 pre 6.602e+01 delta 3.096e+00 f 1.004e+04 |g| 5.934e+02 CG  19
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 26 act 7.435e+01 pre 8.383e+01 delta 3.096e+00 f 9.972e+03 |g| 6.811e+02 CG  30
# iter 26 act 7.435e+01 pre 8.383e+01 delta 3.096e+00 f 9.972e+03 |g| 6.811e+02 CG  30
# iter 27 act 3.202e+01 pre 3.170e+01 delta 3.096e+00 f 9.898e+03 |g| 1.025e+03 CG  15
# iter 27 act 3.202e+01 pre 3.170e+01 delta 3.096e+00 f 9.898e+03 |g| 1.025e+03 CG  15
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 28 act 4.482e+01 pre 4.370e+01 delta 3.184e+00 f 9.866e+03 |g| 3.113e+02 CG  24
# iter 28 act 4.482e+01 pre 4.370e+01 delta 3.184e+00 f 9.866e+03 |g| 3.113e+02 CG  24
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 29 act 3.898e+01 pre 5.172e+01 delta 3.184e+00 f 9.821e+03 |g| 4.966e+02 CG  37
# iter 29 act 3.898e+01 pre 5.172e+01 delta 3.184e+00 f 9.821e+03 |g| 4.966e+02 CG  37
# iter 30 act 2.339e+01 pre 2.453e+01 delta 3.184e+00 f 9.782e+03 |g| 6.674e+02 CG  18
# iter 30 act 2.339e+01 pre 2.453e+01 delta 3.184e+00 f 9.782e+03 |g| 6.674e+02 CG  18
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 31 act 2.609e+01 pre 2.534e+01 delta 3.291e+00 f 9.758e+03 |g| 2.190e+02 CG  37
# iter 31 act 2.609e+01 pre 2.534e+01 delta 3.291e+00 f 9.758e+03 |g| 2.190e+02 CG  37
# iter 32 act 1.068e+01 pre 1.208e+01 delta 3.291e+00 f 9.732e+03 |g| 3.035e+02 CG  30
# iter 32 act 1.068e+01 pre 1.208e+01 delta 3.291e+00 f 9.732e+03 |g| 3.035e+02 CG  30
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 33 act 9.370e+00 pre 1.387e+01 delta 2.495e+00 f 9.722e+03 |g| 1.890e+02 CG  44
# iter 33 act 9.370e+00 pre 1.387e+01 delta 2.495e+00 f 9.722e+03 |g| 1.890e+02 CG  44
# iter 34 act 7.537e+00 pre 7.563e+00 delta 2.495e+00 f 9.712e+03 |g| 1.726e+02 CG  28
# iter 34 act 7.537e+00 pre 7.563e+00 delta 2.495e+00 f 9.712e+03 |g| 1.726e+02 CG  28
# iter 35 act 1.223e+00 pre 3.070e+00 delta 1.271e+00 f 9.705e+03 |g| 4.981e+01 CG  84
# iter 35 act 1.223e+00 pre 3.070e+00 delta 1.271e+00 f 9.705e+03 |g| 4.981e+01 CG  84
# iter 36 act 1.816e+00 pre 1.816e+00 delta 1.271e+00 f 9.703e+03 |g| 5.707e+01 CG  27
# iter 36 act 1.816e+00 pre 1.816e+00 delta 1.271e+00 f 9.703e+03 |g| 5.707e+01 CG  27
# iter  1 act 3.196e+04 pre 3.192e+04 delta 9.210e-02 f 5.000e+04 |g| 6.941e+05 CG   1
# iter  1 act 3.196e+04 pre 3.192e+04 delta 9.210e-02 f 5.000e+04 |g| 6.941e+05 CG   1
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter  2 act 9.708e+02 pre 9.565e+02 delta 1.839e-01 f 1.804e+04 |g| 1.579e+04 CG   2
# iter  2 act 9.708e+02 pre 9.565e+02 delta 1.839e-01 f 1.804e+04 |g| 1.579e+04 CG   2
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter  3 act 8.904e+02 pre 8.294e+02 delta 2.263e-01 f 1.706e+04 |g| 1.191e+04 CG   2
# iter  3 act 8.904e+02 pre 8.294e+02 delta 2.263e-01 f 1.706e+04 |g| 1.191e+04 CG   2
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter  4 act 6.866e+02 pre 6.806e+02 delta 2.943e-01 f 1.617e+04 |g| 1.197e+04 CG   2
# iter  4 act 6.866e+02 pre 6.806e+02 delta 2.943e-01 f 1.617e+04 |g| 1.197e+04 CG   2
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter  5 act 9.371e+02 pre 9.288e+02 delta 4.433e-01 f 1.549e+04 |g| 8.424e+03 CG   3
# iter  5 act 9.371e+02 pre 9.288e+02 delta 4.433e-01 f 1.549e+04 |g| 8.424e+03 CG   3
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter  6 act 1.010e+03 pre 9.865e+02 delta 9.060e-01 f 1.455e+04 |g| 8.929e+03 CG   3
# iter  6 act 1.010e+03 pre 9.865e+02 delta 9.060e-01 f 1.455e+04 |g| 8.929e+03 CG   3
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter  7 act 1.284e+03 pre 1.211e+03 delta 1.575e+00 f 1.354e+04 |g| 5.654e+03 CG   3
# iter  7 act 1.284e+03 pre 1.211e+03 delta 1.575e+00 f 1.354e+04 |g| 5.654e+03 CG   3
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter  8 act 1.257e+03 pre 1.093e+03 delta 2.101e+00 f 1.226e+04 |g| 7.713e+03 CG   5
# iter  8 act 1.257e+03 pre 1.093e+03 delta 2.101e+00 f 1.226e+04 |g| 7.713e+03 CG   5
# iter  9 act 1.882e+02 pre 1.777e+02 delta 2.101e+00 f 1.100e+04 |g| 1.241e+04 CG   3
# iter  9 act 1.882e+02 pre 1.777e+02 delta 2.101e+00 f 1.100e+04 |g| 1.241e+04 CG   3
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 10 act 8.718e+02 pre 8.035e+02 delta 2.588e+00 f 1.081e+04 |g| 3.291e+03 CG   6
# iter 10 act 8.718e+02 pre 8.035e+02 delta 2.588e+00 f 1.081e+04 |g| 3.291e+03 CG   6
# iter 11 act 2.864e+02 pre 2.846e+02 delta 2.588e+00 f 9.941e+03 |g| 7.891e+03 CG   6
# iter 11 act 2.864e+02 pre 2.846e+02 delta 2.588e+00 f 9.941e+03 |g| 7.891e+03 CG   6
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 12 act 6.692e+02 pre 6.184e+02 delta 3.587e+00 f 9.654e+03 |g| 4.008e+03 CG   9
# iter 12 act 6.692e+02 pre 6.184e+02 delta 3.587e+00 f 9.654e+03 |g| 4.008e+03 CG   9
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 13 act 5.994e+02 pre 5.792e+02 delta 4.297e+00 f 8.985e+03 |g| 1.517e+03 CG  11
# iter 13 act 5.994e+02 pre 5.792e+02 delta 4.297e+00 f 8.985e+03 |g| 1.517e+03 CG  11
# iter 14 act 9.329e+01 pre 8.994e+01 delta 4.297e+00 f 8.386e+03 |g| 4.612e+03 CG   4
# iter 14 act 9.329e+01 pre 8.994e+01 delta 4.297e+00 f 8.386e+03 |g| 4.612e+03 CG   4
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 15 act 3.679e+02 pre 3.558e+02 delta 4.686e+00 f 8.292e+03 |g| 1.207e+03 CG  13
# iter 15 act 3.679e+02 pre 3.558e+02 delta 4.686e+00 f 8.292e+03 |g| 1.207e+03 CG  13
# iter 16 act 1.212e+02 pre 1.146e+02 delta 4.686e+00 f 7.925e+03 |g| 3.272e+03 CG   9
# iter 16 act 1.212e+02 pre 1.146e+02 delta 4.686e+00 f 7.925e+03 |g| 3.272e+03 CG   9
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 17 act 2.346e+02 pre 2.286e+02 delta 4.953e+00 f 7.803e+03 |g| 1.224e+03 CG  15
# iter 17 act 2.346e+02 pre 2.286e+02 delta 4.953e+00 f 7.803e+03 |g| 1.224e+03 CG  15
# iter 18 act 1.012e+02 pre 1.029e+02 delta 4.953e+00 f 7.569e+03 |g| 2.307e+03 CG  10
# iter 18 act 1.012e+02 pre 1.029e+02 delta 4.953e+00 f 7.569e+03 |g| 2.307e+03 CG  10
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 19 act 1.670e+02 pre 1.628e+02 delta 5.436e+00 f 7.468e+03 |g| 1.089e+03 CG  17
# iter 19 act 1.670e+02 pre 1.628e+02 delta 5.436e+00 f 7.468e+03 |g| 1.089e+03 CG  17
# iter 20 act 6.607e+01 pre 6.691e+01 delta 5.436e+00 f 7.301e+03 |g| 1.374e+03 CG  11
# iter 20 act 6.607e+01 pre 6.691e+01 delta 5.436e+00 f 7.301e+03 |g| 1.374e+03 CG  11
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 21 act 1.139e+02 pre 1.141e+02 delta 5.472e+00 f 7.235e+03 |g| 6.359e+02 CG  21
# iter 21 act 1.139e+02 pre 1.141e+02 delta 5.472e+00 f 7.235e+03 |g| 6.359e+02 CG  21
# iter 22 act 5.372e+01 pre 5.324e+01 delta 5.472e+00 f 7.121e+03 |g| 1.062e+03 CG  15
# iter 22 act 5.372e+01 pre 5.324e+01 delta 5.472e+00 f 7.121e+03 |g| 1.062e+03 CG  15
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 23 act 6.936e+01 pre 7.289e+01 delta 5.472e+00 f 7.067e+03 |g| 4.990e+02 CG  25
# iter 23 act 6.936e+01 pre 7.289e+01 delta 5.472e+00 f 7.067e+03 |g| 4.990e+02 CG  25
# iter 24 act 2.740e+01 pre 2.748e+01 delta 5.472e+00 f 6.998e+03 |g| 6.119e+02 CG  16
# iter 24 act 2.740e+01 pre 2.748e+01 delta 5.472e+00 f 6.998e+03 |g| 6.119e+02 CG  16
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 25 act 3.810e+01 pre 3.889e+01 delta 5.472e+00 f 6.970e+03 |g| 2.310e+02 CG  36
# iter 25 act 3.810e+01 pre 3.889e+01 delta 5.472e+00 f 6.970e+03 |g| 2.310e+02 CG  36
# iter 26 act 8.219e+00 pre 8.327e+00 delta 5.472e+00 f 6.932e+03 |g| 3.116e+02 CG  18
# iter 26 act 8.219e+00 pre 8.327e+00 delta 5.472e+00 f 6.932e+03 |g| 3.116e+02 CG  18
# iter 27 act 8.098e+00 pre 8.679e+00 delta 5.472e+00 f 6.924e+03 |g| 8.068e+01 CG  68
# iter 27 act 8.098e+00 pre 8.679e+00 delta 5.472e+00 f 6.924e+03 |g| 8.068e+01 CG  68
# iter 28 act 6.241e-01 pre 6.187e-01 delta 5.472e+00 f 6.916e+03 |g| 5.793e+01 CG  25
# iter 28 act 6.241e-01 pre 6.187e-01 delta 5.472e+00 f 6.916e+03 |g| 5.793e+01 CG  25
# iter  1 act 3.062e+04 pre 3.059e+04 delta 9.012e-02 f 5.000e+04 |g| 6.794e+05 CG   1
# iter  1 act 3.062e+04 pre 3.059e+04 delta 9.012e-02 f 5.000e+04 |g| 6.794e+05 CG   1
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter  2 act 9.749e+02 pre 9.774e+02 delta 1.949e-01 f 1.938e+04 |g| 1.505e+04 CG   2
# iter  2 act 9.749e+02 pre 9.774e+02 delta 1.949e-01 f 1.938e+04 |g| 1.505e+04 CG   2
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter  3 act 1.199e+03 pre 1.209e+03 delta 2.900e-01 f 1.841e+04 |g| 2.013e+04 CG   2
# iter  3 act 1.199e+03 pre 1.209e+03 delta 2.900e-01 f 1.841e+04 |g| 2.013e+04 CG   2
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter  4 act 1.124e+03 pre 1.179e+03 delta 3.176e-01 f 1.721e+04 |g| 1.088e+04 CG   3
# iter  4 act 1.124e+03 pre 1.179e+03 delta 3.176e-01 f 1.721e+04 |g| 1.088e+04 CG   3
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter  5 act 1.193e+03 pre 1.153e+03 delta 3.882e-01 f 1.609e+04 |g| 1.488e+04 CG   3
# iter  5 act 1.193e+03 pre 1.153e+03 delta 3.882e-01 f 1.609e+04 |g| 1.488e+04 CG   3
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter  6 act 8.741e+02 pre 8.510e+02 delta 4.763e-01 f 1.489e+04 |g| 1.213e+04 CG   4
# iter  6 act 8.741e+02 pre 8.510e+02 delta 4.763e-01 f 1.489e+04 |g| 1.213e+04 CG   4
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter  7 act 8.359e+02 pre 7.636e+02 delta 7.275e-01 f 1.402e+04 |g| 9.619e+03 CG   4
# iter  7 act 8.359e+02 pre 7.636e+02 delta 7.275e-01 f 1.402e+04 |g| 9.619e+03 CG   4
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter  8 act 6.869e+02 pre 6.298e+02 delta 8.293e-01 f 1.318e+04 |g| 8.885e+03 CG   5
# iter  8 act 6.869e+02 pre 6.298e+02 delta 8.293e-01 f 1.318e+04 |g| 8.885e+03 CG   5
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter  9 act 7.020e+02 pre 7.129e+02 delta 8.558e-01 f 1.250e+04 |g| 1.055e+04 CG   6
# iter  9 act 7.020e+02 pre 7.129e+02 delta 8.558e-01 f 1.250e+04 |g| 1.055e+04 CG   6
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 10 act 6.647e+02 pre 6.134e+02 delta 1.034e+00 f 1.179e+04 |g| 1.125e+04 CG   5
# iter 10 act 6.647e+02 pre 6.134e+02 delta 1.034e+00 f 1.179e+04 |g| 1.125e+04 CG   5
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 11 act 5.192e+02 pre 4.999e+02 delta 1.181e+00 f 1.113e+04 |g| 8.982e+03 CG   6
# iter 11 act 5.192e+02 pre 4.999e+02 delta 1.181e+00 f 1.113e+04 |g| 8.982e+03 CG   6
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 12 act 5.082e+02 pre 4.857e+02 delta 1.534e+00 f 1.061e+04 |g| 5.550e+03 CG   7
# iter 12 act 5.082e+02 pre 4.857e+02 delta 1.534e+00 f 1.061e+04 |g| 5.550e+03 CG   7
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 13 act 4.173e+02 pre 3.896e+02 delta 1.836e+00 f 1.010e+04 |g| 4.735e+03 CG   9
# iter 13 act 4.173e+02 pre 3.896e+02 delta 1.836e+00 f 1.010e+04 |g| 4.735e+03 CG   9
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 14 act 3.839e+02 pre 3.826e+02 delta 2.042e+00 f 9.685e+03 |g| 3.653e+03 CG  11
# iter 14 act 3.839e+02 pre 3.826e+02 delta 2.042e+00 f 9.685e+03 |g| 3.653e+03 CG  11
# iter 15 act 1.239e+02 pre 1.175e+02 delta 2.042e+00 f 9.301e+03 |g| 4.556e+03 CG   6
# iter 15 act 1.239e+02 pre 1.175e+02 delta 2.042e+00 f 9.301e+03 |g| 4.556e+03 CG   6
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 16 act 2.530e+02 pre 2.445e+02 delta 2.696e+00 f 9.177e+03 |g| 1.671e+03 CG   9
# iter 16 act 2.530e+02 pre 2.445e+02 delta 2.696e+00 f 9.177e+03 |g| 1.671e+03 CG   9
# iter 17 act 8.753e+01 pre 8.554e+01 delta 2.696e+00 f 8.924e+03 |g| 4.248e+03 CG   6
# iter 17 act 8.753e+01 pre 8.554e+01 delta 2.696e+00 f 8.924e+03 |g| 4.248e+03 CG   6
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 18 act 2.286e+02 pre 2.270e+02 delta 3.152e+00 f 8.837e+03 |g| 1.178e+03 CG  10
# iter 18 act 2.286e+02 pre 2.270e+02 delta 3.152e+00 f 8.837e+03 |g| 1.178e+03 CG  10
# iter 19 act 1.045e+02 pre 1.005e+02 delta 3.152e+00 f 8.608e+03 |g| 2.365e+03 CG   9
# iter 19 act 1.045e+02 pre 1.005e+02 delta 3.152e+00 f 8.608e+03 |g| 2.365e+03 CG   9
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 20 act 1.951e+02 pre 1.887e+02 delta 3.843e+00 f 8.503e+03 |g| 1.302e+03 CG  11
# iter 20 act 1.951e+02 pre 1.887e+02 delta 3.843e+00 f 8.503e+03 |g| 1.302e+03 CG  11
# iter 21 act 8.072e+01 pre 7.946e+01 delta 3.843e+00 f 8.308e+03 |g| 1.866e+03 CG   9
# iter 21 act 8.072e+01 pre 7.946e+01 delta 3.843e+00 f 8.308e+03 |g| 1.866e+03 CG   9
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 22 act 1.550e+02 pre 1.544e+02 delta 3.934e+00 f 8.228e+03 |g| 1.061e+03 CG  13
# iter 22 act 1.550e+02 pre 1.544e+02 delta 3.934e+00 f 8.228e+03 |g| 1.061e+03 CG  13
# iter 23 act 9.032e+01 pre 8.798e+01 delta 3.934e+00 f 8.073e+03 |g| 1.688e+03 CG  10
# iter 23 act 9.032e+01 pre 8.798e+01 delta 3.934e+00 f 8.073e+03 |g| 1.688e+03 CG  10
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 24 act 1.214e+02 pre 1.166e+02 delta 4.179e+00 f 7.982e+03 |g| 1.062e+03 CG  17
# iter 24 act 1.214e+02 pre 1.166e+02 delta 4.179e+00 f 7.982e+03 |g| 1.062e+03 CG  17
# iter 25 act 7.084e+01 pre 7.284e+01 delta 4.179e+00 f 7.861e+03 |g| 1.135e+03 CG  15
# iter 25 act 7.084e+01 pre 7.284e+01 delta 4.179e+00 f 7.861e+03 |g| 1.135e+03 CG  15
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 26 act 9.714e+01 pre 9.545e+01 delta 4.637e+00 f 7.790e+03 |g| 8.331e+02 CG  18
# iter 26 act 9.714e+01 pre 9.545e+01 delta 4.637e+00 f 7.790e+03 |g| 8.331e+02 CG  18
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 27 act 1.086e+02 pre 1.121e+02 delta 4.637e+00 f 7.693e+03 |g| 7.874e+02 CG  30
# iter 27 act 1.086e+02 pre 1.121e+02 delta 4.637e+00 f 7.693e+03 |g| 7.874e+02 CG  30
# iter 28 act 3.322e+01 pre 3.297e+01 delta 4.637e+00 f 7.584e+03 |g| 1.158e+03 CG  13
# iter 28 act 3.322e+01 pre 3.297e+01 delta 4.637e+00 f 7.584e+03 |g| 1.158e+03 CG  13
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 29 act 5.342e+01 pre 5.277e+01 delta 4.876e+00 f 7.551e+03 |g| 3.815e+02 CG  31
# iter 29 act 5.342e+01 pre 5.277e+01 delta 4.876e+00 f 7.551e+03 |g| 3.815e+02 CG  31
# iter 30 act 1.955e+01 pre 2.012e+01 delta 4.876e+00 f 7.498e+03 |g| 4.831e+02 CG  23
# iter 30 act 1.955e+01 pre 2.012e+01 delta 4.876e+00 f 7.498e+03 |g| 4.831e+02 CG  23
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter 31 act 2.640e+01 pre 2.650e+01 delta 4.905e+00 f 7.478e+03 |g| 2.798e+02 CG  37
# iter 31 act 2.640e+01 pre 2.650e+01 delta 4.905e+00 f 7.478e+03 |g| 2.798e+02 CG  37
# iter 32 act 5.756e+00 pre 5.813e+00 delta 4.905e+00 f 7.452e+03 |g| 1.789e+02 CG  30
# iter 32 act 5.756e+00 pre 5.813e+00 delta 4.905e+00 f 7.452e+03 |g| 1.789e+02 CG  30
# iter 33 act 3.823e+00 pre 3.839e+00 delta 4.905e+00 f 7.446e+03 |g| 7.242e+01 CG  73
# iter 33 act 3.823e+00 pre 3.839e+00 delta 4.905e+00 f 7.446e+03 |g| 7.242e+01 CG  73
# iter 34 act 1.372e-01 pre 1.384e-01 delta 4.905e+00 f 7.442e+03 |g| 1.830e+01 CG  49
# iter 34 act 1.372e-01 pre 1.384e-01 delta 4.905e+00 f 7.442e+03 |g| 1.830e+01 CG  49
# iter  1 act 3.070e+04 pre 3.067e+04 delta 9.030e-02 f 5.000e+04 |g| 6.799e+05 CG   1
# iter  1 act 3.070e+04 pre 3.067e+04 delta 9.030e-02 f 5.000e+04 |g| 6.799e+05 CG   1
# cg reaches trust region boundary
# cg reaches trust region boundary
# iter  2 act 1.442e+03 pre 1.364e+03 delta 1.047e-01 f 1.930e+04 |g| 2.809e+04 CG   2
# iter  2 act 1.442e+03 pre 1.364e+03 delta 1.047e-01 f 1.930e+04 |g| 2.809e+04 CG   2

# %% [markdown]
# ## 4. Make Predictions on Test Set
#
# Predict on scaled test features and time inference.

# %%
print("\n" + "="*60)
print("LinearSVC Prediction Phase")
print("="*60)

infer_start = time.time()
y_pred = best_model.predict(test_features_scaled)
infer_time = time.time() - infer_start
print(f"✓ Inference time: {infer_time:.2f} s")
print(f"Predictions shape: {y_pred.shape} | Unique classes: {np.unique(y_pred)}")

# %% [markdown]
# ## 5. Evaluate Classification Performance
#
# Compute accuracy, confusion matrix, and classification report; compare to expected baseline.

# %%
accuracy = accuracy_score(test_labels, y_pred)
cm = confusion_matrix(test_labels, y_pred)
report = classification_report(test_labels, y_pred, target_names=[f"Class {i}" for i in range(10)], digits=4)

in_range = expected_min <= accuracy <= expected_max
range_text = "✓ Within expected range" if in_range else "⚠ Outside expected range"

print(f"Accuracy: {accuracy:.4f} ({accuracy*100:.2f}%)")
print(f"Expected: {expected_min*100:.0f}% - {expected_max*100:.0f}% {range_text}\n")
print("Classification Report:\n" + report)

metrics_path = output_folder / "linear_svc_metrics.pkl"
with open(metrics_path, "wb") as f:
    pickle.dump({
        "accuracy": accuracy,
        "cm": cm,
        "report": report,
        "load_time": load_time,
        "scale_time": scale_time,
        "train_time": train_time,
        "infer_time": infer_time,
        "best_iter": best_iter,
        "val_acc": best_acc
    }, f)
print(f"✓ Metrics saved: {metrics_path}")

# %% [markdown]
# ## 6. Visualize Confusion Matrix and Metrics
#
# Heatmap, accuracy vs expected range, per-class accuracy bars, and distributions.

# %%
fig, axes = plt.subplots(2, 2, figsize=(15, 12))

# 1. Confusion Matrix Heatmap
ax1 = axes[0, 0]
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=ax1,
            xticklabels=range(10), yticklabels=range(10), cbar_kws={'label': 'Count'})
ax1.set_title('Confusion Matrix - LinearSVC')
ax1.set_xlabel('Predicted Label')
ax1.set_ylabel('True Label')

# 2. Accuracy Comparison
ax2 = axes[0, 1]
categories = ['Model Accuracy', 'Expected Min', 'Expected Max']
values = [accuracy*100, expected_min*100, expected_max*100]
colors = ['#2ecc71' if (expected_min*100 <= values[0] <= expected_max*100) else '#e74c3c', '#3498db', '#3498db']
bars = ax2.bar(categories, values, color=colors, alpha=0.7, edgecolor='black', linewidth=1.5)
ax2.set_ylabel('Accuracy (%)')
ax2.set_title('Model Accuracy vs Expected Range')
ax2.set_ylim([0, 100])
ax2.axhline(y=expected_min*100, color='blue', linestyle='--', alpha=0.5)
ax2.axhline(y=expected_max*100, color='blue', linestyle='--', alpha=0.5)
for bar, val in zip(bars, values):
    ax2.text(bar.get_x() + bar.get_width()/2., val, f'{val:.2f}%', ha='center', va='bottom', fontsize=10)
ax2.grid(axis='y', alpha=0.3)

# 3. Per-class Accuracy
ax3 = axes[1, 0]
per_class_accuracy = cm.diagonal() / cm.sum(axis=1)
bars = ax3.bar(range(10), per_class_accuracy*100, color='#3498db', alpha=0.7, edgecolor='black', linewidth=1.5)
ax3.set_xlabel('Class')
ax3.set_ylabel('Accuracy (%)')
ax3.set_title('Per-Class Accuracy')
ax3.set_ylim([0, 105])
ax3.set_xticks(range(10))
ax3.grid(axis='y', alpha=0.3)
for i, (bar, acc) in enumerate(zip(bars, per_class_accuracy)):
    ax3.text(bar.get_x() + bar.get_width()/2., acc*100, f'{acc*100:.1f}%', ha='center', va='bottom', fontsize=9)

# 4. Prediction Distribution
ax4 = axes[1, 1]
pred_counts = np.bincount(y_pred, minlength=10)
true_counts = np.bincount(test_labels, minlength=10)
x = np.arange(10)
width = 0.35
ax4.bar(x - width/2, true_counts, width, label='True', alpha=0.8, color='#2ecc71', edgecolor='black')
ax4.bar(x + width/2, pred_counts, width, label='Predicted', alpha=0.8, color='#3498db', edgecolor='black')
ax4.set_xlabel('Class')
ax4.set_ylabel('Count')
ax4.set_title('True vs Predicted Class Distribution')
ax4.set_xticks(x)
ax4.legend()
ax4.grid(axis='y', alpha=0.3)

plt.tight_layout()
plot_path = output_folder / "linear_svc_evaluation.png"
plt.savefig(str(plot_path), dpi=150, bbox_inches='tight')
print(f"✓ Visualization saved: {plot_path}")
plt.show()

# %% [markdown]
# ## 7. Per-Class Accuracy Analysis
#
# Detailed per-class table, easiest/hardest classes, and animal vs vehicle confusion patterns.

# %%
cifar10_classes = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

per_class_total = cm.sum(axis=1)
per_class_correct = cm.diagonal()
per_class_accuracy = per_class_correct / per_class_total

results_table = pd.DataFrame({
    'Class': range(10),
    'Name': cifar10_classes,
    'Total Samples': per_class_total,
    'Correct': per_class_correct,
    'Incorrect': per_class_total - per_class_correct,
    'Accuracy (%)': per_class_accuracy * 100
}).sort_values('Accuracy (%)', ascending=False)

print(results_table.to_string(index=False))

easiest_idx = int(results_table.iloc[0]['Class'])
hardest_idx = int(results_table.iloc[-1]['Class'])
print("\nKey Findings:")
print(f"✓ Easiest class: {cifar10_classes[easiest_idx]} (Class {easiest_idx}) - {results_table.iloc[0]['Accuracy (%)']:.2f}%")
print(f"✗ Hardest class: {cifar10_classes[hardest_idx]} (Class {hardest_idx}) - {results_table.iloc[-1]['Accuracy (%)']:.2f}%")
print(f"Accuracy range: {per_class_accuracy.min()*100:.2f}% - {per_class_accuracy.max()*100:.2f}%")
print(f"Std deviation: {per_class_accuracy.std()*100:.2f}%")

animal_classes = [2, 3, 4, 5, 6, 7]
vehicle_classes = [0, 1, 8, 9]
animal_confusion = cm[np.ix_(animal_classes, animal_classes)]
vehicle_confusion = cm[np.ix_(vehicle_classes, vehicle_classes)]
animal_confusion_rate = (animal_confusion.sum() - animal_confusion.diagonal().sum()) / animal_confusion.sum()
vehicle_confusion_rate = (vehicle_confusion.sum() - vehicle_confusion.diagonal().sum()) / vehicle_confusion.sum()
print(f"Animal-to-animal confusion rate: {animal_confusion_rate*100:.2f}%")
print(f"Vehicle-to-vehicle confusion rate: {vehicle_confusion_rate*100:.2f}%")

# %% [markdown]
# ## 8. Compare with Baseline Methods
#
# Comparison table across methods and expected ranges.

# %%
baseline = pd.DataFrame([
    {"Method": "LinearSVC on GPU2 features", "Accuracy": accuracy*100, "Training Time (s)": train_time, "Inference Time (s)": infer_time, "Notes": "This work, early-stopping heuristic"},
    {"Method": "SVM RBF on GPU2 features", "Accuracy": None, "Training Time (s)": None, "Inference Time (s)": None, "Notes": "See RBF notebook"},
    {"Method": "Random baseline", "Accuracy": 10.0, "Training Time (s)": None, "Inference Time (s)": None, "Notes": "Chance level"},
    {"Method": "Linear SVM on raw pixels", "Accuracy": 40.0, "Training Time (s)": None, "Inference Time (s)": None, "Notes": "No feature learning"},
    {"Method": "End-to-end CNN (ResNet-18)", "Accuracy": 78.0, "Training Time (s)": None, "Inference Time (s)": None, "Notes": "Typical benchmark"}
])
print(baseline.to_string(index=False))
